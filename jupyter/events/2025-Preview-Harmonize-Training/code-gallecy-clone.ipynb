# %% [markdown]
# ### Start download code-gallery repository
#
# At the terminal:

# %%
git clone https://github.com/Harmonize-Brazil/code-gallery.git
# Out:
# Cloning into 'code-gallery'...
# remote: Enumerating objects: 497, done.
# remote: Counting objects: 100% (259/259), done.
# remote: Compressing objects: 100% (188/188), done.
# remote: Total 497 (delta 137), reused 147 (delta 68), pack-reused 238 (from 1)
# Receiving objects: 100% (497/497), 25.17 MiB | 12.82 MiB/s, done.
# Resolving deltas: 100% (200/200), done.
